# %% [markdown]
# # Positive fixture — secret leaked into notebook cell output
# The source code uses os.environ correctly, but a prior run printed the AWS key value
# into the cell output and was committed. Must produce secrets.leaked-in-notebook-output
# at CRITICAL severity.

# %%
import os
# Source code is fine — reads from env
key = os.getenv("AWS_ACCESS_KEY_ID")
# But a prior run printed the value, leaking it into the saved output
print(f"AWS_ACCESS_KEY_ID={key}")
# Out:
# AWS_ACCESS_KEY_ID=AKIAIOSFODNN7EXAMPLE

# %%
# Simulate a DataFrame display that showed a token column value
import pandas as pd
df = pd.DataFrame({'Token': ['ghp_ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789ab']})
df
# Out:
# Token: ghp_ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789ab
