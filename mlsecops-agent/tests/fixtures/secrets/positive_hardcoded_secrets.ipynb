# %% [markdown]
# # Positive fixture — hardcoded secrets in source
# Must flag at least 5 distinct rule ids (openai-api-key, anthropic-api-key, aws-access-key, huggingface-token, github-token, slack-token, private-key-block, url-with-credentials).

# %%
# Hardcoded OpenAI key (old style)
openai_key = "sk-ABCDEFGHIJKLMNOPQRSTUVWXYZabcdef"

# %%
# Hardcoded Anthropic key
anthropic_key = "sk-ant-api03-ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789abcdef"

# %%
# Hardcoded AWS access key
aws_key = "AKIAIOSFODNN7EXAMPLE"

# %%
# Hardcoded HuggingFace token
hf_token = "hf_ABCDEFGHIJKLMNOPQRSTUVWXYZabcdef"

# %%
# Hardcoded GitHub PAT
gh_token = "ghp_ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789ab"

# %%
# Hardcoded Slack token
slack_token = "xoxb-123456789012-ABCDEFGHIJKLMN"

# %%
# Embedded private key block
pem = """-----BEGIN RSA PRIVATE KEY-----
MIIEowIBAAKCAQEA...
-----END RSA PRIVATE KEY-----"""

# %%
# URL with embedded credentials
db_url = "https://admin:s3cr3tpassword@database.example.com/mydb"
