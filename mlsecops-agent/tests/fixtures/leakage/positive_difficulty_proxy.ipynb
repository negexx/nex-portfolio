# %% [markdown]
# # Positive fixture: difficulty_level column in feature list (label-proxy)
# The feature columns list retains difficulty_level, which is a known label proxy.

# %%
import pandas as pd

# difficulty_level encodes the target class — leaving it in features causes leakage
feature_cols = [
    'duration',
    'protocol_type',
    'src_bytes',
    'dst_bytes',
    'difficulty_level',
    'count',
    'srv_count',
]

X = df[feature_cols]
