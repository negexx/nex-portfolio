# %% [markdown]
# # Positive fixture
# Contains: one unpinned !pip install, one untrusted !wget. Must produce 2+ findings.

# %%
# !pip install imbalanced-learn -q
# !pip install numpy==1.26.4

# %%
# !wget https://raw.githubusercontent.com/example/data/main/file.csv -O data.csv
