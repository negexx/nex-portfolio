# %% [markdown]
# # Negative fixture
# All installs pinned. The !wget is paired with a sha256 check. Expect zero findings.

# %%
# !pip install numpy==1.26.4
# !pip install scikit-learn==1.5.2
# !pip install imbalanced-learn>=0.12,<0.13

# %%
# !wget https://example.com/data.csv -O data.csv
# !echo 'a1b2c3...  data.csv' | sha256sum -c -
